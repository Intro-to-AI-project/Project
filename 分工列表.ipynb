# %% [markdown]
# ### 例子:
# 1. 王纪洲-完成-guidance

# %% [markdown]
# ### 正式填写处
# 1. 王纪洲-完成-数据summary和离群值
# 2. 韩卓衡-部分完成-pair plot 和 相关性分析
# 3. 杨子然-完成-在数据预处理的结果上初步可视化
# 4. 杨子然-开始- k-means检测聚类, 可视化聚类特征
# 5. 韩卓衡-尝试使用经典PCA方法并可视化结果
