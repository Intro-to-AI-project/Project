# %% [markdown]
# # Python 入门

# %% [markdown]
# ## 需要了解的包

# %% [markdown]
# 1. Pandas  用于数据分析和处理, 可以支持多维cube
# 2. matplotlib  python中用于绘图的包, 比较简单(缺点是api比较混乱, 写的比较差)
# 3. Seaborn 可以画很多高级的图像, 比如热量图等等. (可以现查)
# 4. sklearn 传统机器学习包, 有大量机器学习库
# 5. XGBoost 经典集成学习库
# 6. pytorch 主流深度学习库
